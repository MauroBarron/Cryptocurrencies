# %%
# Dependencies
import pandas as pd

# %%
# Load Data
file_path = "./Resources/iris.csv"
iris_df = pd.read_csv(file_path)
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Drop class column
new_iris_df = iris_df.drop(['class'], axis=1)
new_iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
# Reorder colummns
neworder = ['sepal_length','petal_length','sepal_width','petal_width']
new_iris_df=new_iris_df.reindex(columns=neworder)
new_iris_df.head()
# Out:
#    sepal_length  petal_length  sepal_width  petal_width
# 0           5.1           1.4          3.5          0.2
# 1           4.9           1.4          3.0          0.2
# 2           4.7           1.3          3.2          0.2
# 3           4.6           1.5          3.1          0.2
# 4           5.0           1.4          3.6          0.2

# %%
# Export to CSV
output_file_path = "./Resources/new_iris_data.csv"
new_iris_df.to_csv(output_file_path, index=False)

# %%
# Load Shopping Data.
file_path = "./Resources/shopping_data.csv"
df_shopping = pd.read_csv(file_path, encoding="ISO-8859-1")
df_shopping.head()
# Out:
#    CustomerID Card Member   Age  Annual Income  Spending Score (1-100)
# 0           1         Yes  19.0          15000                    39.0
# 1           2         Yes  21.0          15000                    81.0
# 2           3          No  20.0          16000                     6.0
# 3           4          No  23.0          16000                    77.0
# 4           5          No  31.0          17000                    40.0

# %%
## Look at the datatypes
df_shopping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203 entries, 0 to 202
# Data columns (total 5 columns):
# CustomerID                203 non-null int64
# Card Member               201 non-null object
# Age                       201 non-null float64
# Annual Income             203 non-null int64
# Spending Score (1-100)    202 non-null float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 8.1+ KB

# %%
# Find Null Values
for column in df_shopping.columns:
    print(f"Column{column} has {df_shopping[column].isnull().sum()} null values")
# Out:
# ColumnCustomerID has 0 null values
# ColumnCard Member has 2 null values
# ColumnAge has 2 null values
# ColumnAnnual Income has 0 null values
# ColumnSpending Score (1-100) has 1 null values

# %%
# Drop null rows
df_shopping = df_shopping.dropna()
df_shopping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 0 to 202
# Data columns (total 5 columns):
# CustomerID                200 non-null int64
# Card Member               200 non-null object
# Age                       200 non-null float64
# Annual Income             200 non-null int64
# Spending Score (1-100)    200 non-null float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 9.4+ KB

# %%
# Find duplicate entries
print(f"Duplicate entries: {df_shopping.duplicated().sum()}")
# Out:
# Duplicate entries: 0

# %%
# Remove Customer ID
df_shopping.drop(columns=["CustomerID"], inplace=True)
df_shopping.head()
# Out:
#   Card Member   Age  Annual Income  Spending Score (1-100)
# 0         Yes  19.0          15000                    39.0
# 1         Yes  21.0          15000                    81.0
# 2          No  20.0          16000                     6.0
# 3          No  23.0          16000                    77.0
# 4          No  31.0          17000                    40.0

# %%
# Transform String column using Apply Method
def change_string(member):
    if member == "Yes":
        return 1
    else:
        return 0
df_shopping["Card Member"] = df_shopping["Card Member"].apply(change_string)
df_shopping.head()
# Out:
#    Card Member   Age  Annual Income  Spending Score (1-100)
# 0            1  19.0          15000                    39.0
# 1            1  21.0          15000                    81.0
# 2            0  20.0          16000                     6.0
# 3            0  23.0          16000                    77.0
# 4            0  31.0          17000                    40.0

# %%
# Transform annual income
df_shopping["Annual Income"] = df_shopping["Annual Income"] / 1000
df_shopping.head()
# Out:
#    Card Member   Age  Annual Income  Spending Score (1-100)
# 0            1  19.0           15.0                    39.0
# 1            1  21.0           15.0                    81.0
# 2            0  20.0           16.0                     6.0
# 3            0  23.0           16.0                    77.0
# 4            0  31.0           17.0                    40.0

# %%
## 18.2.5 Skill Drill - Rename columns
df_shopping.rename(columns={"Card Member":"Card_Member", "Annual Income":"Annual_Income", "Spending Score (1-100)":"Spending_Score"}, inplace = True)
df_shopping.head()
# Out:
#    Card_Member   Age  Annual_Income  Spending_Score
# 0            1  19.0           15.0            39.0
# 1            1  21.0           15.0            81.0
# 2            0  20.0           16.0             6.0
# 3            0  23.0           16.0            77.0
# 4            0  31.0           17.0            40.0

# %%
# Save cleaned data
file_path = "./Resources/shopping_data_cleaned.csv"
df_shopping.to_csv(file_path, index=False)
